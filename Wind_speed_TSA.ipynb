# %% [markdown]
# <a href="https://colab.research.google.com/github/harshdhiman-ai/wind-speed-TSA/blob/main/Wind_speed_TSA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
url='https://raw.githubusercontent.com/harshdhiman-ai/wind-speed-TSA/main/lillgrund-sweden-sep-2020-10-min.csv'
df=pd.read_csv(url)
df.head()
df.drop(columns=['Rainfall','Snowfall','Snow depth','Short-wave irradiation'],inplace=True)
df.head()
# Out:
#      # Date UT time  Temperature  ...  Pressure  Wind speed  Wind direction
# 0  9/1/2020    0:10       284.62  ...   1017.26        3.81           43.83
# 1  9/1/2020    0:20       284.52  ...   1017.29        3.82           44.54
# 2  9/1/2020    0:30       284.43  ...   1017.32        3.82           45.24
# 3  9/1/2020    0:40       284.33  ...   1017.36        3.82           45.76
# 4  9/1/2020    0:50       284.24  ...   1017.40        3.81           46.12
#
# [5 rows x 7 columns]

# %%
ws=df.iloc[:,5]
ws.describe()
ws.index=np.arange(0,len(ws),1)
ws.head
# Out:
# <bound method NDFrame.head of 0       3.81
# 1       3.82
# 2       3.82
# 3       3.82
# 4       3.81
#         ...
# 4315    4.62
# 4316    4.64
# 4317    4.66
# 4318    4.67
# 4319    4.68
# Name: Wind speed, Length: 4320, dtype: float64>

# %%
def plot_df(ws, x, y, title="", xlabel='Samples', ylabel='Wind speed (m/sec)', dpi=300):
    plt.figure(figsize=(16,5), dpi=dpi)
    plt.plot(x, y, color='tab:blue')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()

plot_df(df, x=ws.index, y=ws.values, title='Wind speed for Lillgrund wind farm, Sweden')
